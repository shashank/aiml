# %% [markdown]
# Q.1 Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %% [markdown]
# Q.2 Get the Dataset

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Q3. Plot the distribution of total_bill in the given dataset.

# %%
sns.distplot(tips['total_bill']);
# plt.show()

# %% [markdown]
# Q.4 - Plot the destribution plot for tips.

# %%
sns.distplot(tips['tip']);
# plt.show()

# %%
sns.jointplot(tips['total_bill'], tips['tip'])

# %% [markdown]
# Q5. Make a joint plot between tip and total bill.

# %%
sns.jointplot(tips['total_bill'], tips['tip'], kind='resid');

# %% [markdown]
# Q6. Give additional attribute kind = "hex" in the above plot.

# %%
sns.jointplot(tips['total_bill'], tips['tip'], kind = "hex")
# Out:
# C:\Users\Mohita_BGL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Mohita_BGL\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Q7. Make pairplot between total bill and tip.

# %%
sns.pairplot(tips[['total_bill','tip']]);

# %%
sns.pairplot(tips[['total_bill','tip']]);

# %% [markdown]
# Q.8 -  Make striplot between sex and tip.

# %%
sns.stripplot(tips['sex'], tips['tip']);

# %%
sns.boxplot(data=tips, x='sex', y='tip', hue_order='tip', col='day');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-b81ee231cece> in <module>
# ----> 1 sns.boxplot(data=tips, x='sex', y='tip', hue_order='tip', col='day');
#
# ~/Documents/Anaconda/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2239     kwargs.update(dict(whis=whis))
#    2240
# -> 2241     plotter.plot(ax, kwargs)
#    2242     return ax
#    2243
#
# ~/Documents/Anaconda/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in plot(self, ax, boxplot_kws)
#     537     def plot(self, ax, boxplot_kws):
#     538         """Make the plot."""
# --> 539         self.draw_boxplot(ax, boxplot_kws)
#     540         self.annotate_axes(ax)
#     541         if self.orient == "h":
#
# ~/Documents/Anaconda/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in draw_boxplot(self, ax, kws)
#     469                     continue
#     470
# --> 471                 artist_dict = ax.boxplot(box_data,
#     472                                          vert=vert,
#     473                                          patch_artist=True,
#
# ~/Documents/Anaconda/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     294                 f"for the old name will be dropped %(removal)s.")
#     295             kwargs[new] = kwargs.pop(old)
# --> 296         return func(*args, **kwargs)
#     297
#     298     # wrapper() must keep the same documented signature as func(): if we
#
# ~/Documents/Anaconda/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: boxplot() got an unexpected keyword argument 'col'

# %% [markdown]
# Q.9 - What other plots you can make for tip and sex variable.Plot them.

# %% [markdown]
# Q.10 Make bar plot with day and total bill.

# %%
sns.barplot(tips['day'], tips['total_bill']);

# %% [markdown]
# Q.11 - Make a plot to count total males and females for each day.

# %%
sns.countplot(tips['day'], hue = tips['sex'])

# %% [markdown]
# Q.12 -  Use factorplot to plot multiple categorical variables like day, smoker, peoplecount.

# %%
sns.catplot(x = "day",
               y = "size",
               hue = "size",
               col = "smoker",
               data = tips,
               kind = "bar"
              );

# %% [markdown]
# Q.13 - Use lmplot() to plot the relation between total bill and tip.

# %%
sns.lmplot(x = "total_bill",
               y = "tip", data = tips, hue='sex')

# %% [markdown]
# Q.14 - Plot the above graph for male and female.

# %%
sns.lmplot(x = "total_bill",
               y = "tip", data = tips, hue = "sex")

# %% [markdown]
# Q.14 - Plot the Q.13 graph for smoker and non-smoker.

# %%
sns.lmplot(x = "total_bill",
               y = "tip", data = tips, hue = "smoker");
